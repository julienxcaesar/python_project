# %% [markdown]
# Python Data Analyis Project by Julien Stewart

# %% [markdown]
# ##import pandas, numpy, and matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##import Data

# %%
df = pd.read_csv('Salaries.csv')

# %% [markdown]
# ##info about dataset

# %% [markdown]
# What is the average Total Pay?
# What is the highest total pay plus benefits?
# Information about a person name David Kushner
# What is David Kushner base pay?
# Who are some employees that make over 300k?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# #dataframe head and tail

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# ##dataframe first 10 rows

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %% [markdown]
# ##dataframe last 10 rows

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle  BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant      0.0
# 148645  148646  Carolyn A Wilson     Human Services Technician      0.0
# 148646  148647      Not provided                  Not provided      NaN
# 148647  148648    Joann Anderson   Communications Dispatcher 2      0.0
# 148648  148649       Leon Walker                     Custodian      0.0
# 148649  148650     Roy I Tillery                     Custodian      0.0
# 148650  148651      Not provided                  Not provided      NaN
# 148651  148652      Not provided                  Not provided      NaN
# 148652  148653      Not provided                  Not provided      NaN
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148644          0.0      0.00       0.0      0.00              0.00  2014
# ...

# %% [markdown]
# ##index dataframe

# %%
df.loc[0]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %%
df.loc[4]
# Out:
# Id                                                             5
# EmployeeName                                     PATRICK GARDNER
# JobTitle            DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# BasePay                                                 134401.6
# OvertimePay                                               9737.0
# OtherPay                                               182234.59
# Benefits                                                     NaN
# TotalPay                                               326373.19
# TotalPayBenefits                                       326373.19
# Year                                                        2011
# Notes                                                        NaN
# Agency                                             San Francisco
# Status                                                       NaN
# Name: 4, dtype: object

# %%
## Find Employee named David Kushner

# %%
df[df['EmployeeName'] == 'DAVID KUSHNER']
# Out:
#    Id   EmployeeName                        JobTitle    BasePay  OvertimePay  \
# 7   8  DAVID KUSHNER  DEPUTY DIRECTOR OF INVESTMENTS  256576.96          0.0
#
#    OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 7   51322.5       NaN  307899.46         307899.46  2011    NaN
#
#           Agency  Status
# 7  San Francisco     NaN

# %%
## Find employees who make more than 300k base pay

# %%
df[df['BasePay'] > 300000]
# Out:
#             Id          EmployeeName                      JobTitle    BasePay  \
# 36160    36161          Gregory Suhr               Chief of Police  302578.00
# 72925    72926        Gregory P Suhr               Chief of Police  319275.01
# 72926    72927  Joanne M Hayes-White        Chief, Fire Department  313686.01
# 72929    72930         Robert L Shaw  Dep Dir for Investments, Ret  315572.01
# 72931    72932     Harlan L Kelly-Jr   Executive Contract Employee  313312.52
# 72932    72933         John L Martin                   Dept Head V  311758.96
# 72933    72934      Edward D Reiskin    Gen Mgr, Public Trnsp Dept  305307.89
# 110532  110533            Amy P Hart             Asst Med Examiner  318835.49
# 110534  110535        Gregory P Suhr               Chief of Police  307450.04
# 110535  110536  Joanne M Hayes-White        Chief, Fire Department  302068.00
# 110537  110538         John L Martin                   Dept Head V  311298.55
# ...

# %%
##How much does David Kushner make in Base Salary?

# %%
df[df['EmployeeName'] == 'DAVID KUSHNER']['BasePay']
# Out:
# 7    256576.96
# Name: BasePay, dtype: float64

# %%
#sorted dataframe

# %%
sorted_df = df.sort_index(ascending = False)

# %%
sorted_df
# Out:
#             Id       EmployeeName  \
# 148653  148654          Joe Lopez
# 148652  148653       Not provided
# 148651  148652       Not provided
# 148650  148651       Not provided
# 148649  148650      Roy I Tillery
# ...        ...                ...
# 4            5    PATRICK GARDNER
# 3            4  CHRISTOPHER CHONG
# 2            3     ALBERT PARDINI
# 1            2       GARY JIMENEZ
# 0            1     NATHANIEL FORD
#
#                                               JobTitle    BasePay  \
# 148653                      Counselor, Log Cabin Ranch       0.00
# 148652                                    Not provided        NaN
# 148651                                    Not provided        NaN
# 148650                                    Not provided        NaN
# 148649                                       Custodian       0.00
# ...                                                ...        ...
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...

# %%
pay_sorted = df.sort_values(by=['TotalPay'], ascending = False)

# %%
## Top 10 Salaries in dataframe

# %%
pay_sorted.head(10)
# Out:
#             Id          EmployeeName  \
# 0            1        NATHANIEL FORD
# 1            2          GARY JIMENEZ
# 110531  110532           David Shinn
# 110532  110533            Amy P Hart
# 36159    36160        Gary Altenberg
# 36167    36168         John Goldberg
# 72927    72928           Samson  Lai
# 110536  110537       Ellen G Moffatt
# 110533  110534  William J Coaker Jr.
# 72925    72926        Gregory P Suhr
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 110531                                  Deputy Chief 3  129150.01
# 110532                               Asst Med Examiner  318835.49
# 36159                     Lieutenant, Fire Suppression  128808.87
# 36167                                        Captain 3  104404.00
# 72927                   Battalion Chief, Fire Suppress  186236.42
# ...

# %%
## What is the average Total Pay?

# %%
df['TotalPay'].mean()
# Out:
# 74768.321971703

# %%
##What is the highest total pay plus benefits?

# %%
df['TotalPayBenefits'].max()
# Out:
# 567595.43

# %%
##Nathaniel Ford

# %%
df[df['TotalPayBenefits'] == df['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# ##Group By Statements

# %%
#Sum of Base Pay per Job Title

# %%
df.groupby(['JobTitle'])['BasePay'].sum()
# Out:
# JobTitle
# ACCOUNT CLERK                                     3593966.94
# ACCOUNTANT                                         233215.86
# ACCOUNTANT INTERN                                 1379167.87
# ACPO,JuvP, Juv Prob (SFERS)                         62290.78
# ACUPUNCTURIST                                       66374.40
#                                                      ...
# X-RAY LABORATORY AIDE                             1239284.10
# X-Ray Laboratory Aide                             4608638.71
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS      52609.91
# Youth Comm Advisor                                 156311.83
# ZOO CURATOR                                         43148.00
# Name: BasePay, Length: 2159, dtype: float64

# %%
#Group by Sum of basep pay and benefits

# %%
df.groupby(['JobTitle'])[['BasePay', 'Benefits']].sum()
# Out:
#                                                    BasePay    Benefits
# JobTitle
# ACCOUNT CLERK                                   3593966.94        0.00
# ACCOUNTANT                                       233215.86        0.00
# ACCOUNTANT INTERN                               1379167.87        0.00
# ACPO,JuvP, Juv Prob (SFERS)                       62290.78    17975.59
# ACUPUNCTURIST                                     66374.40        0.00
# ...                                                    ...         ...
# X-RAY LABORATORY AIDE                           1239284.10        0.00
# X-Ray Laboratory Aide                           4608638.71  1869718.05
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.91        0.00
# Youth Comm Advisor                               156311.83    74816.97
# ZOO CURATOR                                       43148.00        0.00
#
# [2159 rows x 2 columns]

# %%
# Histogram plot of Base Pay

# %%
df['Benefits'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ##Thank You !
